# %%
import tensorflow as tf
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import cv2

# %%
from glob import glob

img_paths = []

for img_path in glob("/kaggle/input/utkface-new/UTKFace/*.jpg"):
    img_paths.append(img_path)

# %%
len(img_paths)
# Out:
# 23708

# %%
X = []
Y = []
from tqdm import tqdm

for path in tqdm(img_paths):
    img = cv2.imread(path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    img = cv2.resize(img, (128, 128)) 
    img = np.array(img)/ 255
    X.append(img)
    
    y = str(path).split("/")[-1].split("_")[0:2]
    Y.append(y)
# Out:
# 100%|██████████| 23708/23708 [02:50<00:00, 139.13it/s]

# %%
X_test = []
Y_test = []


test_image_paths = []

for img_path in glob("/kaggle/input/utkface-new/crop_part1/*.jpg"):
    test_image_paths.append(img_path)

for path in tqdm(test_image_paths):
    img = cv2.imread(path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    img = cv2.resize(img, (128, 128)) 
    img = np.array(img)/ 255
    X_test.append(img)
    
    y = str(path).split("/")[-1].split("_")[0:2]
    Y_test.append(y)
# Out:
# 100%|██████████| 9780/9780 [01:21<00:00, 120.63it/s]

# %%
X = np.array(X)
Y = np.array(Y)
len(X), len(Y)
# Out:
# (23708, 23708)

# %%
X_test = np.array(X_test)
Y_test = np.array(Y_test)

# %%
X_train = X

# %%
len(X_train), len(X_test)
# Out:
# (23708, 9780)

# %%
Y_train = np.array(Y).astype(np.float32)

# %%
Y_train_age = Y_train[:, 0]
Y_train_gender = Y_train[:, 1]

# %%
Y_test = np.array(Y_test).astype(np.float32)
Y_test_age = Y_test[:, 0]
Y_test_gender = Y_test[:, 1]

# %%
import random
rand_num = random.choice(range(len(X_train)))
plt.imshow(X_train[rand_num])
print(Y_train[rand_num])
# Out:
# [26.  1.]

# %%
plt.imshow(X_test[rand_num])
print(Y_test[rand_num])
# Out:
# [75.  0.]

# %%
mobilenet = tf.keras.applications.MobileNetV2(
    input_shape=(128, 128, 1),
    alpha=1.0,
    include_top=False,
    weights=None,
    input_tensor=None,
    pooling=None
)

# %%
from keras.layers import Dense, GlobalAveragePooling2D, Flatten, Dropout
from keras.models import Model

# %%
x = mobilenet.layers[-1].output
x = GlobalAveragePooling2D(data_format=None)(x)
x = Dropout(0.5)(x)

dense_gender1 = Dense(256, activation="relu")(x)
dropout_gender1 = Dropout(0.3)(dense_gender1)

dense_age1 = Dense(256, activation="relu")(x)
dropout_age1 = Dropout(0.3)(dense_age1)


predictions_gender = Dense(1, activation="sigmoid", name="gender_prediction")(dropout_gender1)
predictions_age = Dense(1, activation="relu", name="age_prediction")(dropout_age1)

# %%
model = Model(inputs=mobilenet.input, outputs=[predictions_gender, predictions_age])

model.compile(
    loss=["binary_crossentropy", "mae"],
    optimizer="adam",
    metrics=["accuracy"]
)

# %%
from tensorflow.keras.utils import plot_model
plot_model(model, show_shapes=True)

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
callback_list = [
    EarlyStopping(monitor="val_loss", patience=20),
    ModelCheckpoint(filepath="AgeGender_best.h5", verbose=1, monitor="val_loss", save_best_only=True)
]

# %%
history = model.fit(x=X_train, y=[Y_train_gender, Y_train_age], batch_size=32, epochs=30, validation_split=0.2, callbacks=[callback_list])
# Out:
# Epoch 1/30
# 593/593 [==============================] - ETA: 0s - loss: 12.1163 - gender_prediction_loss: 0.6516 - age_prediction_loss: 11.4648 - gender_prediction_accuracy: 0.6308 - age_prediction_accuracy: 0.0466
# Epoch 1: val_loss improved from inf to 17.08022, saving model to AgeGender_best.h5
# 593/593 [==============================] - 61s 47ms/step - loss: 12.1163 - gender_prediction_loss: 0.6516 - age_prediction_loss: 11.4648 - gender_prediction_accuracy: 0.6308 - age_prediction_accuracy: 0.0466 - val_loss: 17.0802 - val_gender_prediction_loss: 0.8173 - val_age_prediction_loss: 16.2629 - val_gender_prediction_accuracy: 0.5299 - val_age_prediction_accuracy: 0.0462
# Epoch 2/30
# 592/593 [============================>.] - ETA: 0s - loss: 9.3089 - gender_prediction_loss: 0.5481 - age_prediction_loss: 8.7608 - gender_prediction_accuracy: 0.7167 - age_prediction_accuracy: 0.0475
# Epoch 2: val_loss improved from 17.08022 to 16.83235, saving model to AgeGender_best.h5
# 593/593 [==============================] - 26s 43ms/step - loss: 9.3072 - gender_prediction_loss: 0.5479 - age_prediction_loss: 8.7593 - gender_prediction_accuracy: 0.7168 - age_prediction_accuracy: 0.0476 - val_loss: 16.8323 - val_gender_prediction_loss: 1.7745 - val_age_prediction_loss: 15.0579 - val_gender_prediction_accuracy: 0.5299 - val_age_prediction_accuracy: 0.0462
# Epoch 3/30
# 592/593 [============================>.] - ETA: 0s - loss: 8.4270 - gender_prediction_loss: 0.4801 - age_prediction_loss: 7.9469 - gender_prediction_accuracy: 0.7690 - age_prediction_accuracy: 0.0477
# Epoch 3: val_loss did not improve from 16.83235
# 593/593 [==============================] - 25s 42ms/step - loss: 8.4278 - gender_prediction_loss: 0.4800 - age_prediction_loss: 7.9477 - gender_prediction_accuracy: 0.7690 - age_prediction_accuracy: 0.0477 - val_loss: 17.0789 - val_gender_prediction_loss: 2.0201 - val_age_prediction_loss: 15.0587 - val_gender_prediction_accuracy: 0.5299 - val_age_prediction_accuracy: 0.0462
# Epoch 4/30
# 593/593 [==============================] - ETA: 0s - loss: 7.9784 - gender_prediction_loss: 0.4505 - age_prediction_loss: 7.5279 - gender_prediction_accuracy: 0.7853 - age_prediction_accuracy: 0.0476
# Epoch 4: val_loss did not improve from 16.83235
# 593/593 [==============================] - 25s 42ms/step - loss: 7.9784 - gender_prediction_loss: 0.4505 - age_prediction_loss: 7.5279 - gender_prediction_accuracy: 0.7853 - age_prediction_accuracy: 0.0476 - val_loss: 17.5786 - val_gender_prediction_loss: 2.1339 - val_age_prediction_loss: 15.4447 - val_gender_prediction_accuracy: 0.5299 - val_age_prediction_accuracy: 0.0462
# Epoch 5/30
# 592/593 [============================>.] - ETA: 0s - loss: 7.5466 - gender_prediction_loss: 0.4073 - age_prediction_loss: 7.1393 - gender_prediction_accuracy: 0.8079 - age_prediction_accuracy: 0.0477
# Epoch 5: val_loss did not improve from 16.83235
# 593/593 [==============================] - 25s 42ms/step - loss: 7.5491 - gender_prediction_loss: 0.4072 - age_prediction_loss: 7.1419 - gender_prediction_accuracy: 0.8080 - age_prediction_accuracy: 0.0477 - val_loss: 17.1028 - val_gender_prediction_loss: 1.9220 - val_age_prediction_loss: 15.1808 - val_gender_prediction_accuracy: 0.5299 - val_age_prediction_accuracy: 0.0462
# Epoch 6/30
# 593/593 [==============================] - ETA: 0s - loss: 7.3487 - gender_prediction_loss: 0.3862 - age_prediction_loss: 6.9625 - gender_prediction_accuracy: 0.8150 - age_prediction_accuracy: 0.0477
# Epoch 6: val_loss did not improve from 16.83235
# 593/593 [==============================] - 25s 42ms/step - loss: 7.3487 - gender_prediction_loss: 0.3862 - age_prediction_loss: 6.9625 - gender_prediction_accuracy: 0.8150 - age_prediction_accuracy: 0.0477 - val_loss: 19.8539 - val_gender_prediction_loss: 2.1325 - val_age_prediction_loss: 17.7214 - val_gender_prediction_accuracy: 0.5299 - val_age_prediction_accuracy: 0.0462
# Epoch 7/30
# 592/593 [============================>.] - ETA: 0s - loss: 7.0573 - gender_prediction_loss: 0.3760 - age_prediction_loss: 6.6814 - gender_prediction_accuracy: 0.8266 - age_prediction_accuracy: 0.0476
# Epoch 7: val_loss did not improve from 16.83235
# 593/593 [==============================] - 25s 42ms/step - loss: 7.0569 - gender_prediction_loss: 0.3759 - age_prediction_loss: 6.6810 - gender_prediction_accuracy: 0.8266 - age_prediction_accuracy: 0.0477 - val_loss: 23.0086 - val_gender_prediction_loss: 1.4305 - val_age_prediction_loss: 21.5781 - val_gender_prediction_accuracy: 0.5299 - val_age_prediction_accuracy: 0.0462
# Epoch 8/30
# 593/593 [==============================] - ETA: 0s - loss: 6.8652 - gender_prediction_loss: 0.3615 - age_prediction_loss: 6.5037 - gender_prediction_accuracy: 0.8333 - age_prediction_accuracy: 0.0477
# Epoch 8: val_loss improved from 16.83235 to 11.60978, saving model to AgeGender_best.h5
# 593/593 [==============================] - 26s 43ms/step - loss: 6.8652 - gender_prediction_loss: 0.3615 - age_prediction_loss: 6.5037 - gender_prediction_accuracy: 0.8333 - age_prediction_accuracy: 0.0477 - val_loss: 11.6098 - val_gender_prediction_loss: 0.8075 - val_age_prediction_loss: 10.8023 - val_gender_prediction_accuracy: 0.5909 - val_age_prediction_accuracy: 0.0462
# Epoch 9/30
# 592/593 [============================>.] - ETA: 0s - loss: 6.6147 - gender_prediction_loss: 0.3467 - age_prediction_loss: 6.2681 - gender_prediction_accuracy: 0.8412 - age_prediction_accuracy: 0.0477
# Epoch 9: val_loss improved from 11.60978 to 9.98226, saving model to AgeGender_best.h5
# 593/593 [==============================] - 26s 43ms/step - loss: 6.6144 - gender_prediction_loss: 0.3465 - age_prediction_loss: 6.2679 - gender_prediction_accuracy: 0.8413 - age_prediction_accuracy: 0.0477 - val_loss: 9.9823 - val_gender_prediction_loss: 0.7084 - val_age_prediction_loss: 9.2739 - val_gender_prediction_accuracy: 0.6375 - val_age_prediction_accuracy: 0.0462
# Epoch 10/30
# 593/593 [==============================] - ETA: 0s - loss: 6.4336 - gender_prediction_loss: 0.3320 - age_prediction_loss: 6.1017 - gender_prediction_accuracy: 0.8502 - age_prediction_accuracy: 0.0477
# Epoch 10: val_loss improved from 9.98226 to 9.48831, saving model to AgeGender_best.h5
# 593/593 [==============================] - 26s 43ms/step - loss: 6.4336 - gender_prediction_loss: 0.3320 - age_prediction_loss: 6.1017 - gender_prediction_accuracy: 0.8502 - age_prediction_accuracy: 0.0477 - val_loss: 9.4883 - val_gender_prediction_loss: 0.6361 - val_age_prediction_loss: 8.8522 - val_gender_prediction_accuracy: 0.7117 - val_age_prediction_accuracy: 0.0462
# Epoch 11/30
# 593/593 [==============================] - ETA: 0s - loss: 6.2408 - gender_prediction_loss: 0.3195 - age_prediction_loss: 5.9213 - gender_prediction_accuracy: 0.8543 - age_prediction_accuracy: 0.0477
# Epoch 11: val_loss did not improve from 9.48831
# 593/593 [==============================] - 25s 42ms/step - loss: 6.2408 - gender_prediction_loss: 0.3195 - age_prediction_loss: 5.9213 - gender_prediction_accuracy: 0.8543 - age_prediction_accuracy: 0.0477 - val_loss: 9.8789 - val_gender_prediction_loss: 0.4140 - val_age_prediction_loss: 9.4648 - val_gender_prediction_accuracy: 0.8233 - val_age_prediction_accuracy: 0.0462
# Epoch 12/30
# 593/593 [==============================] - ETA: 0s - loss: 6.1649 - gender_prediction_loss: 0.3104 - age_prediction_loss: 5.8544 - gender_prediction_accuracy: 0.8600 - age_prediction_accuracy: 0.0477
# Epoch 12: val_loss did not improve from 9.48831
# 593/593 [==============================] - 25s 42ms/step - loss: 6.1649 - gender_prediction_loss: 0.3104 - age_prediction_loss: 5.8544 - gender_prediction_accuracy: 0.8600 - age_prediction_accuracy: 0.0477 - val_loss: 11.8415 - val_gender_prediction_loss: 0.5386 - val_age_prediction_loss: 11.3029 - val_gender_prediction_accuracy: 0.7539 - val_age_prediction_accuracy: 0.0462
# Epoch 13/30
# 593/593 [==============================] - ETA: 0s - loss: 5.9522 - gender_prediction_loss: 0.3070 - age_prediction_loss: 5.6452 - gender_prediction_accuracy: 0.8628 - age_prediction_accuracy: 0.0477
# Epoch 13: val_loss improved from 9.48831 to 9.38795, saving model to AgeGender_best.h5
# 593/593 [==============================] - 26s 43ms/step - loss: 5.9522 - gender_prediction_loss: 0.3070 - age_prediction_loss: 5.6452 - gender_prediction_accuracy: 0.8628 - age_prediction_accuracy: 0.0477 - val_loss: 9.3879 - val_gender_prediction_loss: 0.5704 - val_age_prediction_loss: 8.8176 - val_gender_prediction_accuracy: 0.7596 - val_age_prediction_accuracy: 0.0462
# Epoch 14/30
# 593/593 [==============================] - ETA: 0s - loss: 5.8919 - gender_prediction_loss: 0.2994 - age_prediction_loss: 5.5925 - gender_prediction_accuracy: 0.8642 - age_prediction_accuracy: 0.0477
# Epoch 14: val_loss did not improve from 9.38795
# 593/593 [==============================] - 25s 43ms/step - loss: 5.8919 - gender_prediction_loss: 0.2994 - age_prediction_loss: 5.5925 - gender_prediction_accuracy: 0.8642 - age_prediction_accuracy: 0.0477 - val_loss: 10.5775 - val_gender_prediction_loss: 0.4314 - val_age_prediction_loss: 10.1461 - val_gender_prediction_accuracy: 0.8073 - val_age_prediction_accuracy: 0.0462
# Epoch 15/30
# 592/593 [============================>.] - ETA: 0s - loss: 5.7050 - gender_prediction_loss: 0.2910 - age_prediction_loss: 5.4140 - gender_prediction_accuracy: 0.8718 - age_prediction_accuracy: 0.0477
# Epoch 15: val_loss improved from 9.38795 to 8.58744, saving model to AgeGender_best.h5
# 593/593 [==============================] - 26s 44ms/step - loss: 5.7052 - gender_prediction_loss: 0.2911 - age_prediction_loss: 5.4141 - gender_prediction_accuracy: 0.8718 - age_prediction_accuracy: 0.0477 - val_loss: 8.5874 - val_gender_prediction_loss: 0.5897 - val_age_prediction_loss: 7.9978 - val_gender_prediction_accuracy: 0.7469 - val_age_prediction_accuracy: 0.0462
# Epoch 16/30
# 593/593 [==============================] - ETA: 0s - loss: 5.6859 - gender_prediction_loss: 0.2911 - age_prediction_loss: 5.3947 - gender_prediction_accuracy: 0.8697 - age_prediction_accuracy: 0.0477
# Epoch 16: val_loss improved from 8.58744 to 8.29038, saving model to AgeGender_best.h5
# 593/593 [==============================] - 26s 44ms/step - loss: 5.6859 - gender_prediction_loss: 0.2911 - age_prediction_loss: 5.3947 - gender_prediction_accuracy: 0.8697 - age_prediction_accuracy: 0.0477 - val_loss: 8.2904 - val_gender_prediction_loss: 0.3829 - val_age_prediction_loss: 7.9075 - val_gender_prediction_accuracy: 0.8229 - val_age_prediction_accuracy: 0.0462
# Epoch 17/30
# 593/593 [==============================] - ETA: 0s - loss: 5.4942 - gender_prediction_loss: 0.2771 - age_prediction_loss: 5.2171 - gender_prediction_accuracy: 0.8777 - age_prediction_accuracy: 0.0477
# Epoch 17: val_loss did not improve from 8.29038
# 593/593 [==============================] - 25s 43ms/step - loss: 5.4942 - gender_prediction_loss: 0.2771 - age_prediction_loss: 5.2171 - gender_prediction_accuracy: 0.8777 - age_prediction_accuracy: 0.0477 - val_loss: 9.9320 - val_gender_prediction_loss: 0.5846 - val_age_prediction_loss: 9.3474 - val_gender_prediction_accuracy: 0.7474 - val_age_prediction_accuracy: 0.0462
# Epoch 18/30
# 593/593 [==============================] - ETA: 0s - loss: 5.3903 - gender_prediction_loss: 0.2687 - age_prediction_loss: 5.1216 - gender_prediction_accuracy: 0.8818 - age_prediction_accuracy: 0.0477
# Epoch 18: val_loss did not improve from 8.29038
# 593/593 [==============================] - 25s 43ms/step - loss: 5.3903 - gender_prediction_loss: 0.2687 - age_prediction_loss: 5.1216 - gender_prediction_accuracy: 0.8818 - age_prediction_accuracy: 0.0477 - val_loss: 9.3163 - val_gender_prediction_loss: 0.4048 - val_age_prediction_loss: 8.9114 - val_gender_prediction_accuracy: 0.8189 - val_age_prediction_accuracy: 0.0462
# Epoch 19/30
# 593/593 [==============================] - ETA: 0s - loss: 5.3332 - gender_prediction_loss: 0.2715 - age_prediction_loss: 5.0617 - gender_prediction_accuracy: 0.8821 - age_prediction_accuracy: 0.0477
# Epoch 19: val_loss did not improve from 8.29038
# 593/593 [==============================] - 25s 43ms/step - loss: 5.3332 - gender_prediction_loss: 0.2715 - age_prediction_loss: 5.0617 - gender_prediction_accuracy: 0.8821 - age_prediction_accuracy: 0.0477 - val_loss: 8.4724 - val_gender_prediction_loss: 0.3947 - val_age_prediction_loss: 8.0777 - val_gender_prediction_accuracy: 0.8290 - val_age_prediction_accuracy: 0.0462
# Epoch 20/30
# 593/593 [==============================] - ETA: 0s - loss: 5.2280 - gender_prediction_loss: 0.2619 - age_prediction_loss: 4.9661 - gender_prediction_accuracy: 0.8895 - age_prediction_accuracy: 0.0477
# Epoch 20: val_loss did not improve from 8.29038
# 593/593 [==============================] - 25s 43ms/step - loss: 5.2280 - gender_prediction_loss: 0.2619 - age_prediction_loss: 4.9661 - gender_prediction_accuracy: 0.8895 - age_prediction_accuracy: 0.0477 - val_loss: 8.5197 - val_gender_prediction_loss: 0.3441 - val_age_prediction_loss: 8.1756 - val_gender_prediction_accuracy: 0.8454 - val_age_prediction_accuracy: 0.0462
# Epoch 21/30
# 592/593 [============================>.] - ETA: 0s - loss: 5.1295 - gender_prediction_loss: 0.2602 - age_prediction_loss: 4.8693 - gender_prediction_accuracy: 0.8876 - age_prediction_accuracy: 0.0477
# Epoch 21: val_loss did not improve from 8.29038
# 593/593 [==============================] - 25s 43ms/step - loss: 5.1279 - gender_prediction_loss: 0.2602 - age_prediction_loss: 4.8677 - gender_prediction_accuracy: 0.8876 - age_prediction_accuracy: 0.0477 - val_loss: 8.9927 - val_gender_prediction_loss: 0.3703 - val_age_prediction_loss: 8.6224 - val_gender_prediction_accuracy: 0.8279 - val_age_prediction_accuracy: 0.0462
# Epoch 22/30
# 593/593 [==============================] - ETA: 0s - loss: 5.0095 - gender_prediction_loss: 0.2520 - age_prediction_loss: 4.7574 - gender_prediction_accuracy: 0.8891 - age_prediction_accuracy: 0.0477
# Epoch 22: val_loss improved from 8.29038 to 7.60447, saving model to AgeGender_best.h5
# 593/593 [==============================] - 26s 43ms/step - loss: 5.0095 - gender_prediction_loss: 0.2520 - age_prediction_loss: 4.7574 - gender_prediction_accuracy: 0.8891 - age_prediction_accuracy: 0.0477 - val_loss: 7.6045 - val_gender_prediction_loss: 0.3562 - val_age_prediction_loss: 7.2483 - val_gender_prediction_accuracy: 0.8467 - val_age_prediction_accuracy: 0.0462
# Epoch 23/30
# 592/593 [============================>.] - ETA: 0s - loss: 4.9297 - gender_prediction_loss: 0.2504 - age_prediction_loss: 4.6793 - gender_prediction_accuracy: 0.8932 - age_prediction_accuracy: 0.0477
# Epoch 23: val_loss improved from 7.60447 to 6.82336, saving model to AgeGender_best.h5
# 593/593 [==============================] - 26s 43ms/step - loss: 4.9297 - gender_prediction_loss: 0.2503 - age_prediction_loss: 4.6793 - gender_prediction_accuracy: 0.8931 - age_prediction_accuracy: 0.0477 - val_loss: 6.8234 - val_gender_prediction_loss: 0.4301 - val_age_prediction_loss: 6.3932 - val_gender_prediction_accuracy: 0.8229 - val_age_prediction_accuracy: 0.0462
# Epoch 24/30
# 593/593 [==============================] - ETA: 0s - loss: 4.8872 - gender_prediction_loss: 0.2458 - age_prediction_loss: 4.6413 - gender_prediction_accuracy: 0.8931 - age_prediction_accuracy: 0.0477
# Epoch 24: val_loss did not improve from 6.82336
# 593/593 [==============================] - 25s 42ms/step - loss: 4.8872 - gender_prediction_loss: 0.2458 - age_prediction_loss: 4.6413 - gender_prediction_accuracy: 0.8931 - age_prediction_accuracy: 0.0477 - val_loss: 8.0618 - val_gender_prediction_loss: 0.4512 - val_age_prediction_loss: 7.6105 - val_gender_prediction_accuracy: 0.8011 - val_age_prediction_accuracy: 0.0462
# Epoch 25/30
# 592/593 [============================>.] - ETA: 0s - loss: 4.6647 - gender_prediction_loss: 0.2396 - age_prediction_loss: 4.4251 - gender_prediction_accuracy: 0.8956 - age_prediction_accuracy: 0.0477
# Epoch 25: val_loss did not improve from 6.82336
# 593/593 [==============================] - 25s 42ms/step - loss: 4.6633 - gender_prediction_loss: 0.2394 - age_prediction_loss: 4.4239 - gender_prediction_accuracy: 0.8958 - age_prediction_accuracy: 0.0477 - val_loss: 8.0666 - val_gender_prediction_loss: 0.3135 - val_age_prediction_loss: 7.7531 - val_gender_prediction_accuracy: 0.8617 - val_age_prediction_accuracy: 0.0462
# Epoch 26/30
# 593/593 [==============================] - ETA: 0s - loss: 4.6564 - gender_prediction_loss: 0.2399 - age_prediction_loss: 4.4165 - gender_prediction_accuracy: 0.8961 - age_prediction_accuracy: 0.0477
# Epoch 26: val_loss did not improve from 6.82336
# 593/593 [==============================] - 25s 43ms/step - loss: 4.6564 - gender_prediction_loss: 0.2399 - age_prediction_loss: 4.4165 - gender_prediction_accuracy: 0.8961 - age_prediction_accuracy: 0.0477 - val_loss: 7.1431 - val_gender_prediction_loss: 0.4069 - val_age_prediction_loss: 6.7362 - val_gender_prediction_accuracy: 0.8359 - val_age_prediction_accuracy: 0.0462
# Epoch 27/30
# 593/593 [==============================] - ETA: 0s - loss: 4.6570 - gender_prediction_loss: 0.2314 - age_prediction_loss: 4.4256 - gender_prediction_accuracy: 0.9029 - age_prediction_accuracy: 0.0477
# Epoch 27: val_loss did not improve from 6.82336
# 593/593 [==============================] - 25s 42ms/step - loss: 4.6570 - gender_prediction_loss: 0.2314 - age_prediction_loss: 4.4256 - gender_prediction_accuracy: 0.9029 - age_prediction_accuracy: 0.0477 - val_loss: 8.9095 - val_gender_prediction_loss: 0.3576 - val_age_prediction_loss: 8.5519 - val_gender_prediction_accuracy: 0.8577 - val_age_prediction_accuracy: 0.0462
# Epoch 28/30
# 593/593 [==============================] - ETA: 0s - loss: 4.5303 - gender_prediction_loss: 0.2266 - age_prediction_loss: 4.3038 - gender_prediction_accuracy: 0.9018 - age_prediction_accuracy: 0.0477
# Epoch 28: val_loss did not improve from 6.82336
# 593/593 [==============================] - 25s 43ms/step - loss: 4.5303 - gender_prediction_loss: 0.2266 - age_prediction_loss: 4.3038 - gender_prediction_accuracy: 0.9018 - age_prediction_accuracy: 0.0477 - val_loss: 7.0716 - val_gender_prediction_loss: 0.3073 - val_age_prediction_loss: 6.7642 - val_gender_prediction_accuracy: 0.8539 - val_age_prediction_accuracy: 0.0462
# Epoch 29/30
# 592/593 [============================>.] - ETA: 0s - loss: 4.5103 - gender_prediction_loss: 0.2299 - age_prediction_loss: 4.2804 - gender_prediction_accuracy: 0.8992 - age_prediction_accuracy: 0.0477
# Epoch 29: val_loss improved from 6.82336 to 6.55491, saving model to AgeGender_best.h5
# 593/593 [==============================] - 26s 43ms/step - loss: 4.5105 - gender_prediction_loss: 0.2301 - age_prediction_loss: 4.2804 - gender_prediction_accuracy: 0.8990 - age_prediction_accuracy: 0.0477 - val_loss: 6.5549 - val_gender_prediction_loss: 0.3090 - val_age_prediction_loss: 6.2459 - val_gender_prediction_accuracy: 0.8579 - val_age_prediction_accuracy: 0.0462
# Epoch 30/30
# 592/593 [============================>.] - ETA: 0s - loss: 4.5543 - gender_prediction_loss: 0.2204 - age_prediction_loss: 4.3339 - gender_prediction_accuracy: 0.9041 - age_prediction_accuracy: 0.0476
# Epoch 30: val_loss did not improve from 6.55491
# 593/593 [==============================] - 25s 42ms/step - loss: 4.5542 - gender_prediction_loss: 0.2204 - age_prediction_loss: 4.3338 - gender_prediction_accuracy: 0.9040 - age_prediction_accuracy: 0.0477 - val_loss: 6.9080 - val_gender_prediction_loss: 0.3299 - val_age_prediction_loss: 6.5781 - val_gender_prediction_accuracy: 0.8682 - val_age_prediction_accuracy: 0.0462

# %%
acc = history.history['gender_prediction_accuracy']
val_acc = history.history['val_gender_prediction_accuracy']
epochs = range(len(acc))

plt.plot(epochs, acc, 'b', label='Training Accuracy')
plt.plot(epochs, val_acc, 'r', label='Validation Accuracy')
plt.title('Accuracy Graph')
plt.legend()
plt.figure()

loss = history.history['gender_prediction_loss']
val_loss = history.history['val_gender_prediction_loss']

plt.plot(epochs, loss, 'b', label='Training Loss')
plt.plot(epochs, val_loss, 'r', label='Validation Loss')
plt.title('Loss Graph')
plt.legend()
plt.show()

# %%
acc = history.history['age_prediction_accuracy']
val_acc = history.history['val_age_prediction_accuracy']
epochs = range(len(acc))

plt.plot(epochs, acc, 'b', label='Training Accuracy')
plt.plot(epochs, val_acc, 'r', label='Validation Accuracy')
plt.title('Accuracy Graph')
plt.legend()
plt.figure()

loss = history.history['age_prediction_loss']
val_loss = history.history['val_age_prediction_loss']

plt.plot(epochs, loss, 'b', label='Training Loss')
plt.plot(epochs, val_loss, 'r', label='Validation Loss')
plt.title('Loss Graph')
plt.legend()
plt.show()

# %%
gender_dict = {0: "male", 1: "female"}

## Test the model
img_index = 53

print("Original Gender", gender_dict[Y_test_gender[img_index]])
print("Original Age", Y_test_age[img_index])

plt.imshow(X_test[img_index], cmap="gray")

pred = model.predict(X_test[img_index].reshape(1, 128, 128, 1))
pred_gender = gender_dict[round(pred[0][0][0])]
pred_age = round(pred[1][0][0])

print(f"predicted_gender = {pred_gender} and age = {pred_age}")
# model.save_weights("model1.h5")
# Out:
# Original Gender male
# Original Age 16.0
# 1/1 [==============================] - 1s 915ms/step
# predicted_gender = male and age = 21

# %%
img_index = 400
print("Original Gender", gender_dict[Y_test_gender[img_index]])
print("Original Age", Y_test_age[img_index])

plt.imshow(X_test[img_index], cmap="gray")

pred = model.predict(X_test[img_index].reshape(1, 128, 128, 1))
pred_gender = gender_dict[round(pred[0][0][0])]
pred_age = round(pred[1][0][0])

print(f"predicted_gender = {pred_gender} and age = {pred_age}")
# Out:
# Original Gender female
# Original Age 65.0
# 1/1 [==============================] - 0s 26ms/step
# predicted_gender = female and age = 57

# %%
img_index = 250
print("Original Gender", gender_dict[Y_test_gender[img_index]])
print("Original Age", Y_test_age[img_index])

plt.imshow(X_test[img_index], cmap="gray")

pred = model.predict(X_test[img_index].reshape(1, 128, 128, 1))
pred_gender = gender_dict[round(pred[0][0][0])]
pred_age = round(pred[1][0][0])

print(f"predicted_gender = {pred_gender} and age = {pred_age}")
# Out:
# Original Gender male
# Original Age 7.0
# 1/1 [==============================] - 0s 25ms/step
# predicted_gender = female and age = 11
